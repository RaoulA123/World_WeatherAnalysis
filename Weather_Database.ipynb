# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config3 import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
            
        # Append the city information into the city_data list
        city_data.append({"City":city.title(),
                        "Lat":city_lat,
                        "Lng":city_lng,
                        "Max Temp":city_max_temp,
                        "Humidity":city_humidity,
                        "Cloudiness":city_clouds,
                        "Wind Speed":city_wind,
                        "Country":city_country,
                        "Current Weather":city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | cayenne
# Processing Record 3 of Set 1 | bakchar
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | killarney
# Processing Record 6 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 1 | makakilo city
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | andenes
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | raigarh
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | uzhur
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 1 | gdov
# Processing Record 20 of Set 1 | hambantota
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | sur
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | sorland
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | kourou
# Processing Record 29 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | portland
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | sheridan
# Processing Record 35 of Set 1 | vradiyivka
# Processing Record 36 of Set 1 | kavieng
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | riyadh
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | langsa
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | tsumeb
# Processing Record 44 of Set 1 | leningradskiy
# Processing Record 45 of Set 1 | saint george
# Processing Record 46 of Set 1 | ambon
# Processing Record 47 of Set 1 | coquimbo
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | raymond
# Processing Record 2 of Set 2 | marzuq
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | henties bay
# Processing Record 7 of Set 2 | saint-pierre
# Processing Record 8 of Set 2 | flinders
# Processing Record 9 of Set 2 | trinidad
# Processing Record 10 of Set 2 | boa vista
# Processing Record 11 of Set 2 | sao filipe
# Processing Record 12 of Set 2 | teguldet
# Processing Record 13 of Set 2 | vila franca do campo
# Processing Record 14 of Set 2 | turukhansk
# Processing Record 15 of Set 2 | hualmay
# Processing Record 16 of Set 2 | mhlume
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | shakhrinau
# City not found. Skipping...
# Processing Record 21 of Set 2 | preobrazheniye
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | surenavan
# Processing Record 24 of Set 2 | kondopoga
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | cap-aux-meules
# Processing Record 27 of Set 2 | tezu
# Processing Record 28 of Set 2 | nehe
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | gornozavodsk
# Processing Record 31 of Set 2 | chuy
# Processing Record 32 of Set 2 | klaksvik
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | ranong
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | tiksi
# Processing Record 37 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 2 | tucuman
# Processing Record 39 of Set 2 | alexandria
# Processing Record 40 of Set 2 | tabuk
# Processing Record 41 of Set 2 | jalu
# Processing Record 42 of Set 2 | waipawa
# Processing Record 43 of Set 2 | krasnoselkup
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | pakxan
# Processing Record 46 of Set 2 | chachapoyas
# Processing Record 47 of Set 2 | viedma
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | husavik
# Processing Record 1 of Set 3 | asyut
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | mana
# Processing Record 4 of Set 3 | rocha
# Processing Record 5 of Set 3 | krasnyy chikoy
# Processing Record 6 of Set 3 | puerto carreno
# Processing Record 7 of Set 3 | caravelas
# Processing Record 8 of Set 3 | mataura
# Processing Record 9 of Set 3 | odienne
# Processing Record 10 of Set 3 | wanning
# Processing Record 11 of Set 3 | filadelfia
# Processing Record 12 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 3 | lagoa
# Processing Record 14 of Set 3 | souillac
# Processing Record 15 of Set 3 | itaporanga
# Processing Record 16 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | tanout
# Processing Record 20 of Set 3 | nekhayevskiy
# Processing Record 21 of Set 3 | tual
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | cidreira
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | college
# Processing Record 26 of Set 3 | luganville
# Processing Record 27 of Set 3 | berlevag
# Processing Record 28 of Set 3 | blois
# Processing Record 29 of Set 3 | uromi
# Processing Record 30 of Set 3 | vestmanna
# Processing Record 31 of Set 3 | vanimo
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | coihaique
# Processing Record 34 of Set 3 | saint anthony
# Processing Record 35 of Set 3 | high prairie
# Processing Record 36 of Set 3 | bon air
# Processing Record 37 of Set 3 | kerteh
# City not found. Skipping...
# Processing Record 38 of Set 3 | laguna
# Processing Record 39 of Set 3 | taltal
# Processing Record 40 of Set 3 | lodja
# Processing Record 41 of Set 3 | port hardy
# Processing Record 42 of Set 3 | katsuura
# Processing Record 43 of Set 3 | labuan
# Processing Record 44 of Set 3 | bambous virieux
# Processing Record 45 of Set 3 | adrar
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 3 | faya
# Processing Record 50 of Set 3 | nantucket
# Processing Record 1 of Set 4 | anamur
# Processing Record 2 of Set 4 | luanda
# Processing Record 3 of Set 4 | irbit
# Processing Record 4 of Set 4 | voh
# Processing Record 5 of Set 4 | vila velha
# Processing Record 6 of Set 4 | salalah
# Processing Record 7 of Set 4 | atasu
# Processing Record 8 of Set 4 | vangaindrano
# Processing Record 9 of Set 4 | tuatapere
# Processing Record 10 of Set 4 | saurimo
# Processing Record 11 of Set 4 | kununurra
# Processing Record 12 of Set 4 | bilma
# Processing Record 13 of Set 4 | wollongong
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 4 | ludvika
# Processing Record 17 of Set 4 | mikun
# Processing Record 18 of Set 4 | sahrak
# City not found. Skipping...
# Processing Record 19 of Set 4 | grindavik
# Processing Record 20 of Set 4 | bennettsville
# Processing Record 21 of Set 4 | broken hill
# Processing Record 22 of Set 4 | noumea
# Processing Record 23 of Set 4 | akureyri
# Processing Record 24 of Set 4 | zolotinka
# City not found. Skipping...
# Processing Record 25 of Set 4 | santa vitoria do palmar
# Processing Record 26 of Set 4 | nizwa
# Processing Record 27 of Set 4 | kudahuvadhoo
# Processing Record 28 of Set 4 | bonavista
# Processing Record 29 of Set 4 | pizarro
# Processing Record 30 of Set 4 | ronneby
# Processing Record 31 of Set 4 | tome-acu
# City not found. Skipping...
# Processing Record 32 of Set 4 | gasa
# Processing Record 33 of Set 4 | sterling
# Processing Record 34 of Set 4 | singarayakonda
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | ayr
# Processing Record 37 of Set 4 | mehamn
# Processing Record 38 of Set 4 | thompson
# Processing Record 39 of Set 4 | tuktoyaktuk
# Processing Record 40 of Set 4 | yulara
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | maiduguri
# Processing Record 43 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 44 of Set 4 | camana
# Processing Record 45 of Set 4 | bereda
# Processing Record 46 of Set 4 | fuling
# Processing Record 47 of Set 4 | timiryazevskoye
# Processing Record 48 of Set 4 | rudnichnyy
# Processing Record 49 of Set 4 | carnarvon
# Processing Record 50 of Set 4 | kaitangata
# Processing Record 1 of Set 5 | pisco
# Processing Record 2 of Set 5 | utica
# Processing Record 3 of Set 5 | chara
# Processing Record 4 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 5 | pochinki
# Processing Record 6 of Set 5 | tiznit
# Processing Record 7 of Set 5 | bekasi
# Processing Record 8 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 9 of Set 5 | hami
# Processing Record 10 of Set 5 | zanatepec
# City not found. Skipping...
# Processing Record 11 of Set 5 | pathein
# Processing Record 12 of Set 5 | alofi
# Processing Record 13 of Set 5 | hirara
# Processing Record 14 of Set 5 | mahebourg
# Processing Record 15 of Set 5 | broome
# Processing Record 16 of Set 5 | constitucion
# Processing Record 17 of Set 5 | mtwara
# Processing Record 18 of Set 5 | manadhoo
# Processing Record 19 of Set 5 | beni suef
# Processing Record 20 of Set 5 | new richmond
# Processing Record 21 of Set 5 | leh
# Processing Record 22 of Set 5 | sohag
# Processing Record 23 of Set 5 | gurkovo
# Processing Record 24 of Set 5 | bengkulu
# Processing Record 25 of Set 5 | homer
# Processing Record 26 of Set 5 | luderitz
# Processing Record 27 of Set 5 | qena
# Processing Record 28 of Set 5 | iqaluit
# Processing Record 29 of Set 5 | pokhara
# Processing Record 30 of Set 5 | san ramon
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | aklavik
# Processing Record 33 of Set 5 | jorhat
# Processing Record 34 of Set 5 | ellensburg
# Processing Record 35 of Set 5 | westport
# Processing Record 36 of Set 5 | les cayes
# Processing Record 37 of Set 5 | prince rupert
# Processing Record 38 of Set 5 | whitehorse
# Processing Record 39 of Set 5 | kungurtug
# Processing Record 40 of Set 5 | saint-joseph
# Processing Record 41 of Set 5 | narsaq
# Processing Record 42 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 5 | finschhafen
# Processing Record 45 of Set 5 | meulaboh
# Processing Record 46 of Set 5 | namatanai
# Processing Record 47 of Set 5 | wamba
# Processing Record 48 of Set 5 | port hedland
# Processing Record 49 of Set 5 | bethel
# Processing Record 50 of Set 5 | kavaratti
# Processing Record 1 of Set 6 | greystones
# Processing Record 2 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 6 | ginda
# Processing Record 4 of Set 6 | kieta
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | port-cartier
# Processing Record 7 of Set 6 | raudeberg
# Processing Record 8 of Set 6 | mount isa
# Processing Record 9 of Set 6 | tautira
# Processing Record 10 of Set 6 | mar del plata
# Processing Record 11 of Set 6 | bam
# Processing Record 12 of Set 6 | prokuplje
# Processing Record 13 of Set 6 | kerouane
# Processing Record 14 of Set 6 | ostrovnoy
# Processing Record 15 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 6 | bubaque
# Processing Record 17 of Set 6 | hasaki
# Processing Record 18 of Set 6 | mitchell
# Processing Record 19 of Set 6 | prachuap khiri khan
# Processing Record 20 of Set 6 | pangnirtung
# Processing Record 21 of Set 6 | olafsvik
# Processing Record 22 of Set 6 | tigbao
# Processing Record 23 of Set 6 | privokzalnyy
# City not found. Skipping...
# Processing Record 24 of Set 6 | saskylakh
# Processing Record 25 of Set 6 | sobolevo
# Processing Record 26 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 27 of Set 6 | hamilton
# Processing Record 28 of Set 6 | esperance
# Processing Record 29 of Set 6 | khandyga
# Processing Record 30 of Set 6 | tikrit
# Processing Record 31 of Set 6 | kaeo
# Processing Record 32 of Set 6 | tawau
# Processing Record 33 of Set 6 | palmer
# Processing Record 34 of Set 6 | bashmakovo
# Processing Record 35 of Set 6 | saint-paul
# Processing Record 36 of Set 6 | qasigiannguit
# Processing Record 37 of Set 6 | chunoyar
# Processing Record 38 of Set 6 | vitim
# Processing Record 39 of Set 6 | sao felix do xingu
# Processing Record 40 of Set 6 | port lincoln
# Processing Record 41 of Set 6 | rumford
# Processing Record 42 of Set 6 | inhambane
# Processing Record 43 of Set 6 | alihe
# Processing Record 44 of Set 6 | gravdal
# Processing Record 45 of Set 6 | la ronge
# Processing Record 46 of Set 6 | ishigaki
# Processing Record 47 of Set 6 | townsville
# Processing Record 48 of Set 6 | huancavelica
# Processing Record 49 of Set 6 | norman wells
# Processing Record 50 of Set 6 | moose factory
# Processing Record 1 of Set 7 | brae
# Processing Record 2 of Set 7 | puqi
# Processing Record 3 of Set 7 | boden
# Processing Record 4 of Set 7 | baneh
# Processing Record 5 of Set 7 | montepuez
# Processing Record 6 of Set 7 | livadi
# Processing Record 7 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 7 | cururupu
# Processing Record 9 of Set 7 | pevek
# Processing Record 10 of Set 7 | maamba
# Processing Record 11 of Set 7 | okhotsk
# Processing Record 12 of Set 7 | of
# City not found. Skipping...
# Processing Record 13 of Set 7 | biak
# Processing Record 14 of Set 7 | port augusta
# Processing Record 15 of Set 7 | victoria
# Processing Record 16 of Set 7 | egvekinot
# Processing Record 17 of Set 7 | anadyr
# Processing Record 18 of Set 7 | baykit
# Processing Record 19 of Set 7 | terrace
# Processing Record 20 of Set 7 | isangel
# Processing Record 21 of Set 7 | geraldton
# Processing Record 22 of Set 7 | banamba
# Processing Record 23 of Set 7 | namibe
# Processing Record 24 of Set 7 | bayir
# Processing Record 25 of Set 7 | gien
# Processing Record 26 of Set 7 | alyangula
# Processing Record 27 of Set 7 | horta
# Processing Record 28 of Set 7 | ponta do sol
# Processing Record 29 of Set 7 | provideniya
# Processing Record 30 of Set 7 | abnub
# Processing Record 31 of Set 7 | salinopolis
# Processing Record 32 of Set 7 | kikwit
# Processing Record 33 of Set 7 | multan
# Processing Record 34 of Set 7 | bernalillo
# Processing Record 35 of Set 7 | aykhal
# Processing Record 36 of Set 7 | fortuna
# Processing Record 37 of Set 7 | avera
# Processing Record 38 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 39 of Set 7 | asau
# Processing Record 40 of Set 7 | coahuayana
# Processing Record 41 of Set 7 | sorrento
# Processing Record 42 of Set 7 | lompoc
# Processing Record 43 of Set 7 | tabou
# Processing Record 44 of Set 7 | poronaysk
# Processing Record 45 of Set 7 | yunyang
# Processing Record 46 of Set 7 | zlotow
# Processing Record 47 of Set 7 | kasongo-lunda
# Processing Record 48 of Set 7 | abalak
# Processing Record 49 of Set 7 | lavrentiya
# Processing Record 50 of Set 7 | mahuva
# Processing Record 1 of Set 8 | dunedin
# Processing Record 2 of Set 8 | prykolotne
# Processing Record 3 of Set 8 | talnakh
# Processing Record 4 of Set 8 | faanui
# Processing Record 5 of Set 8 | castro
# Processing Record 6 of Set 8 | zabolottya
# City not found. Skipping...
# Processing Record 7 of Set 8 | mandasa
# Processing Record 8 of Set 8 | djougou
# Processing Record 9 of Set 8 | katangli
# Processing Record 10 of Set 8 | zyryanka
# Processing Record 11 of Set 8 | itaituba
# Processing Record 12 of Set 8 | yakeshi
# Processing Record 13 of Set 8 | buraydah
# Processing Record 14 of Set 8 | sechura
# Processing Record 15 of Set 8 | lingao
# Processing Record 16 of Set 8 | pitimbu
# Processing Record 17 of Set 8 | maxixe
# Processing Record 18 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 8 | victoria point
# Processing Record 20 of Set 8 | komsomolskiy
# Processing Record 21 of Set 8 | swellendam
# Processing Record 22 of Set 8 | amapa
# Processing Record 23 of Set 8 | mineiros
# Processing Record 24 of Set 8 | roding
# Processing Record 25 of Set 8 | port blair
# Processing Record 26 of Set 8 | necochea
# Processing Record 27 of Set 8 | marabba
# Processing Record 28 of Set 8 | ancud
# Processing Record 29 of Set 8 | aljezur
# Processing Record 30 of Set 8 | presidencia roque saenz pena
# Processing Record 31 of Set 8 | naze
# Processing Record 32 of Set 8 | beloha
# Processing Record 33 of Set 8 | kamenka
# Processing Record 34 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 8 | sao joao da barra
# Processing Record 36 of Set 8 | kirakira
# Processing Record 37 of Set 8 | rota
# Processing Record 38 of Set 8 | puerto ayacucho
# Processing Record 39 of Set 8 | urumqi
# Processing Record 40 of Set 8 | trairi
# Processing Record 41 of Set 8 | makat
# Processing Record 42 of Set 8 | northam
# Processing Record 43 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 8 | ahipara
# Processing Record 45 of Set 8 | ponte san nicolo
# Processing Record 46 of Set 8 | pangkalanbuun
# Processing Record 47 of Set 8 | malindi
# Processing Record 48 of Set 8 | bathsheba
# Processing Record 49 of Set 8 | sibolga
# Processing Record 50 of Set 8 | el rusio
# Processing Record 1 of Set 9 | catamarca
# Processing Record 2 of Set 9 | lerwick
# Processing Record 3 of Set 9 | cabedelo
# Processing Record 4 of Set 9 | lakes entrance
# Processing Record 5 of Set 9 | rafai
# Processing Record 6 of Set 9 | dashitou
# Processing Record 7 of Set 9 | novopokrovka
# Processing Record 8 of Set 9 | cabo san lucas
# Processing Record 9 of Set 9 | kalmunai
# Processing Record 10 of Set 9 | doha
# Processing Record 11 of Set 9 | tura
# Processing Record 12 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 13 of Set 9 | axim
# Processing Record 14 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 15 of Set 9 | barcelona
# Processing Record 16 of Set 9 | quelimane
# Processing Record 17 of Set 9 | aldama
# Processing Record 18 of Set 9 | crossville
# Processing Record 19 of Set 9 | newton
# Processing Record 20 of Set 9 | dalbandin
# Processing Record 21 of Set 9 | deputatskiy
# Processing Record 22 of Set 9 | ushtobe
# Processing Record 23 of Set 9 | fukue
# Processing Record 24 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 9 | ankang
# Processing Record 26 of Set 9 | saint-ambroise
# Processing Record 27 of Set 9 | flin flon
# Processing Record 28 of Set 9 | mayo
# Processing Record 29 of Set 9 | saldanha
# Processing Record 30 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 9 | mitsamiouli
# Processing Record 32 of Set 9 | ballyshannon
# Processing Record 33 of Set 9 | monte patria
# Processing Record 34 of Set 9 | bukama
# Processing Record 35 of Set 9 | richards bay
# Processing Record 36 of Set 9 | belyy yar
# Processing Record 37 of Set 9 | bom despacho
# Processing Record 38 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 9 | moses lake
# Processing Record 40 of Set 9 | soyo
# Processing Record 41 of Set 9 | walvis bay
# Processing Record 42 of Set 9 | yumen
# Processing Record 43 of Set 9 | pitsunda
# Processing Record 44 of Set 9 | fort nelson
# Processing Record 45 of Set 9 | sitka
# Processing Record 46 of Set 9 | demyansk
# Processing Record 47 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 9 | honningsvag
# Processing Record 49 of Set 9 | kamaishi
# Processing Record 50 of Set 9 | cedral
# Processing Record 1 of Set 10 | supuru de jos
# Processing Record 2 of Set 10 | ayna
# Processing Record 3 of Set 10 | yaan
# Processing Record 4 of Set 10 | kruisfontein
# Processing Record 5 of Set 10 | poum
# Processing Record 6 of Set 10 | abha
# Processing Record 7 of Set 10 | carutapera
# Processing Record 8 of Set 10 | maniitsoq
# Processing Record 9 of Set 10 | padang
# Processing Record 10 of Set 10 | kloulklubed
# Processing Record 11 of Set 10 | havoysund
# Processing Record 12 of Set 10 | north platte
# Processing Record 13 of Set 10 | victor harbor
# Processing Record 14 of Set 10 | manta
# Processing Record 15 of Set 10 | valparaiso
# Processing Record 16 of Set 10 | grand gaube
# Processing Record 17 of Set 10 | nanakuli
# Processing Record 18 of Set 10 | sabha
# Processing Record 19 of Set 10 | yian
# City not found. Skipping...
# Processing Record 20 of Set 10 | waddan
# Processing Record 21 of Set 10 | hervey bay
# Processing Record 22 of Set 10 | hobyo
# Processing Record 23 of Set 10 | chokurdakh
# Processing Record 24 of Set 10 | vao
# Processing Record 25 of Set 10 | china
# Processing Record 26 of Set 10 | kalabo
# Processing Record 27 of Set 10 | plettenberg bay
# Processing Record 28 of Set 10 | hofn
# Processing Record 29 of Set 10 | vardo
# Processing Record 30 of Set 10 | carauari
# Processing Record 31 of Set 10 | hovd
# Processing Record 32 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 10 | gunjur
# Processing Record 34 of Set 10 | sambava
# Processing Record 35 of Set 10 | oranjemund
# Processing Record 36 of Set 10 | dzaoudzi
# Processing Record 37 of Set 10 | banda aceh
# Processing Record 38 of Set 10 | ranau
# Processing Record 39 of Set 10 | suhbaatar
# Processing Record 40 of Set 10 | smithers
# Processing Record 41 of Set 10 | kiruna
# Processing Record 42 of Set 10 | miranda
# Processing Record 43 of Set 10 | esmeraldas
# Processing Record 44 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 45 of Set 10 | jeremie
# Processing Record 46 of Set 10 | soller
# Processing Record 47 of Set 10 | port macquarie
# Processing Record 48 of Set 10 | ottumwa
# Processing Record 49 of Set 10 | halifax
# Processing Record 50 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 11 | sinegorye
# Processing Record 2 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 3 of Set 11 | toronto
# Processing Record 4 of Set 11 | lukovetskiy
# Processing Record 5 of Set 11 | cervantes
# Processing Record 6 of Set 11 | oriximina
# Processing Record 7 of Set 11 | govindgarh
# Processing Record 8 of Set 11 | gharo
# Processing Record 9 of Set 11 | havre-saint-pierre
# Processing Record 10 of Set 11 | kenai
# Processing Record 11 of Set 11 | shimoda
# Processing Record 12 of Set 11 | kutum
# Processing Record 13 of Set 11 | tumarbong
# Processing Record 14 of Set 11 | mareeba
# Processing Record 15 of Set 11 | mankono
# Processing Record 16 of Set 11 | castro alves
# Processing Record 17 of Set 11 | zhangye
# Processing Record 18 of Set 11 | arlit
# Processing Record 19 of Set 11 | abatskoye
# Processing Record 20 of Set 11 | barcelos
# Processing Record 21 of Set 11 | kaihua
# Processing Record 22 of Set 11 | kez
# Processing Record 23 of Set 11 | touros
# Processing Record 24 of Set 11 | gornopravdinsk
# Processing Record 25 of Set 11 | stawell
# Processing Record 26 of Set 11 | san fernando
# Processing Record 27 of Set 11 | bandhi
# Processing Record 28 of Set 11 | mgandu
# Processing Record 29 of Set 11 | gumdag
# Processing Record 30 of Set 11 | altay
# Processing Record 31 of Set 11 | half moon bay
# Processing Record 32 of Set 11 | dingle
# Processing Record 33 of Set 11 | takoradi
# Processing Record 34 of Set 11 | durango
# Processing Record 35 of Set 11 | fairbanks
# Processing Record 36 of Set 11 | tubuala
# Processing Record 37 of Set 11 | collierville
# Processing Record 38 of Set 11 | kitimat
# Processing Record 39 of Set 11 | ayacucho
# Processing Record 40 of Set 11 | ketchikan
# Processing Record 41 of Set 11 | sabang
# Processing Record 42 of Set 11 | balestrand
# Processing Record 43 of Set 11 | vallenar
# Processing Record 44 of Set 11 | codrington
# Processing Record 45 of Set 11 | jerantut
# Processing Record 46 of Set 11 | marawi
# Processing Record 47 of Set 11 | astana
# Processing Record 48 of Set 11 | mayya
# Processing Record 49 of Set 11 | bamnet narong
# Processing Record 50 of Set 11 | vuktyl
# Processing Record 1 of Set 12 | totoro
# Processing Record 2 of Set 12 | shambu
# Processing Record 3 of Set 12 | adiake
# Processing Record 4 of Set 12 | skeldon
# Processing Record 5 of Set 12 | san patricio
# Processing Record 6 of Set 12 | fujin
# Processing Record 7 of Set 12 | dali
# Processing Record 8 of Set 12 | clyde river
# Processing Record 9 of Set 12 | charlottetown
# Processing Record 10 of Set 12 | gorom-gorom
# Processing Record 11 of Set 12 | dubrovytsya
# Processing Record 12 of Set 12 | nioaque
# Processing Record 13 of Set 12 | storforshei
# Processing Record 14 of Set 12 | baruun-urt
# Processing Record 15 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 12 | tungor
# Processing Record 17 of Set 12 | mogadishu
# Processing Record 18 of Set 12 | ohara
# Processing Record 19 of Set 12 | gizo
# Processing Record 20 of Set 12 | agadez
# Processing Record 21 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 12 | atar
# Processing Record 23 of Set 12 | tabas
# Processing Record 24 of Set 12 | zhigansk
# Processing Record 25 of Set 12 | siniscola
# Processing Record 26 of Set 12 | kpandae
# Processing Record 27 of Set 12 | sabla
# Processing Record 28 of Set 12 | nyimba
# Processing Record 29 of Set 12 | mantua
# Processing Record 30 of Set 12 | roald
# Processing Record 31 of Set 12 | nerchinskiy zavod
# Processing Record 32 of Set 12 | willmar
# Processing Record 33 of Set 12 | margate
# Processing Record 34 of Set 12 | fare
# Processing Record 35 of Set 12 | labuhan
# Processing Record 36 of Set 12 | raya
# Processing Record 37 of Set 12 | kurchum
# Processing Record 38 of Set 12 | ventspils
# Processing Record 39 of Set 12 | alice springs
# Processing Record 40 of Set 12 | san juan
# Processing Record 41 of Set 12 | roebourne
# Processing Record 42 of Set 12 | colquechaca
# Processing Record 43 of Set 12 | woodward
# Processing Record 44 of Set 12 | eyl
# Processing Record 45 of Set 12 | tilichiki
# Processing Record 46 of Set 12 | lundazi
# Processing Record 47 of Set 12 | tarabuco
# Processing Record 48 of Set 12 | jimma
# Processing Record 49 of Set 12 | owosso
# Processing Record 50 of Set 12 | santa maria
# Processing Record 1 of Set 13 | dakar
# Processing Record 2 of Set 13 | new iberia
# Processing Record 3 of Set 13 | anloga
# Processing Record 4 of Set 13 | mount gambier
# Processing Record 5 of Set 13 | den helder
# Processing Record 6 of Set 13 | kavarna
# Processing Record 7 of Set 13 | wembley
# Processing Record 8 of Set 13 | aden
# Processing Record 9 of Set 13 | columbus
# Processing Record 10 of Set 13 | antofagasta
# Processing Record 11 of Set 13 | kismayo
# Processing Record 12 of Set 13 | dire
# Processing Record 13 of Set 13 | kilembe
# Processing Record 14 of Set 13 | khorixas
# Processing Record 15 of Set 13 | rizhao
# Processing Record 16 of Set 13 | kyra
# Processing Record 17 of Set 13 | charlestown
# Processing Record 18 of Set 13 | chapais
# Processing Record 19 of Set 13 | santa cruz
# Processing Record 20 of Set 13 | honavar
# Processing Record 21 of Set 13 | bairiki
# Processing Record 22 of Set 13 | otradnoye
# Processing Record 23 of Set 13 | neepawa
# Processing Record 24 of Set 13 | harper
# Processing Record 25 of Set 13 | great yarmouth
# Processing Record 26 of Set 13 | kupang
# Processing Record 27 of Set 13 | askino
# Processing Record 28 of Set 13 | kandi
# Processing Record 29 of Set 13 | saint-louis
# Processing Record 30 of Set 13 | canakkale
# Processing Record 31 of Set 13 | matara
# Processing Record 32 of Set 13 | ulaanbaatar
# Processing Record 33 of Set 13 | togul
# Processing Record 34 of Set 13 | prince george
# Processing Record 35 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 13 | ampanihy
# Processing Record 37 of Set 13 | bhatkal
# Processing Record 38 of Set 13 | zhezkazgan
# Processing Record 39 of Set 13 | moree
# Processing Record 40 of Set 13 | ca mau
# Processing Record 41 of Set 13 | taseyevo
# Processing Record 42 of Set 13 | vila do maio
# Processing Record 43 of Set 13 | bajina basta
# Processing Record 44 of Set 13 | nouadhibou
# Processing Record 45 of Set 13 | brigantine
# Processing Record 46 of Set 13 | kyabe
# Processing Record 47 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 48 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 49 of Set 13 | vaitape
# Processing Record 50 of Set 13 | paamiut
# Processing Record 1 of Set 14 | boone
# Processing Record 2 of Set 14 | el tambo
# Processing Record 3 of Set 14 | wilmington
# Processing Record 4 of Set 14 | praia da vitoria
# Processing Record 5 of Set 14 | agogo
# Processing Record 6 of Set 14 | payo
# Processing Record 7 of Set 14 | secovce
# Processing Record 8 of Set 14 | caetite
# Processing Record 9 of Set 14 | bilibino
# Processing Record 10 of Set 14 | olinda
# Processing Record 11 of Set 14 | amarkantak
# Processing Record 12 of Set 14 | tsevie
# Processing Record 13 of Set 14 | okandja
# City not found. Skipping...
# Processing Record 14 of Set 14 | visnes
# Processing Record 15 of Set 14 | basco
# Processing Record 16 of Set 14 | macapa
# Processing Record 17 of Set 14 | amudat
# Processing Record 18 of Set 14 | karpathos
# Processing Record 19 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 20 of Set 14 | waitati
# Processing Record 21 of Set 14 | port hawkesbury
# Processing Record 22 of Set 14 | bandarbeyla
# Processing Record 23 of Set 14 | sola
# Processing Record 24 of Set 14 | calama
# Processing Record 25 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 14 | presque isle
# Processing Record 27 of Set 14 | trincomalee
# Processing Record 28 of Set 14 | masvingo
# Processing Record 29 of Set 14 | dongsheng
# Processing Record 30 of Set 14 | troy
# Processing Record 31 of Set 14 | mahon
# Processing Record 32 of Set 14 | susanino
# Processing Record 33 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 34 of Set 14 | tutoia
# Processing Record 35 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 36 of Set 14 | tocopilla
# Processing Record 37 of Set 14 | mayumba
# Processing Record 38 of Set 14 | palanas
# Processing Record 39 of Set 14 | enshi
# Processing Record 40 of Set 14 | ossora
# Processing Record 41 of Set 14 | yarmouth
# Processing Record 42 of Set 14 | gimli
# Processing Record 43 of Set 14 | valley city
# Processing Record 44 of Set 14 | bahia de caraquez
# Processing Record 45 of Set 14 | ruteng
# Processing Record 46 of Set 14 | mandalgovi
# Processing Record 47 of Set 14 | acapulco
# Processing Record 48 of Set 14 | skibbereen
# Processing Record 49 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 50 of Set 14 | camacha
# Processing Record 1 of Set 15 | arcachon
# Processing Record 2 of Set 15 | santa helena de goias
# Processing Record 3 of Set 15 | porto novo
# Processing Record 4 of Set 15 | yueyang
# Processing Record 5 of Set 15 | asfi
# Processing Record 6 of Set 15 | mayor pablo lagerenza
# Processing Record 7 of Set 15 | baiyin
# Processing Record 8 of Set 15 | port lavaca
# Processing Record 9 of Set 15 | awbari
# Processing Record 10 of Set 15 | kaita
# Processing Record 11 of Set 15 | swan hill
# Processing Record 12 of Set 15 | grimshaw
# Processing Record 13 of Set 15 | kenora
# Processing Record 14 of Set 15 | bolhrad
# Processing Record 15 of Set 15 | urdoma
# Processing Record 16 of Set 15 | launceston
# Processing Record 17 of Set 15 | baghdad
# Processing Record 18 of Set 15 | kahului
# Processing Record 19 of Set 15 | quatre cocos
# Processing Record 20 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 15 | caiaponia
# Processing Record 22 of Set 15 | pinega
# Processing Record 23 of Set 15 | la quinta
# Processing Record 24 of Set 15 | wuwei
# Processing Record 25 of Set 15 | mega
# Processing Record 26 of Set 15 | omsukchan
# Processing Record 27 of Set 15 | tecoanapa
# Processing Record 28 of Set 15 | votkinsk
# Processing Record 29 of Set 15 | george
# Processing Record 30 of Set 15 | plouzane
# Processing Record 31 of Set 15 | yamada
# Processing Record 32 of Set 15 | bulawayo
# Processing Record 33 of Set 15 | booue
# Processing Record 34 of Set 15 | ambunti
# Processing Record 35 of Set 15 | buchanan
# Processing Record 36 of Set 15 | mariental
# Processing Record 37 of Set 15 | srednekolymsk
# Processing Record 38 of Set 15 | beringovskiy
# Processing Record 39 of Set 15 | kawardha
# Processing Record 40 of Set 15 | yuncheng
# Processing Record 41 of Set 15 | jalor
# Processing Record 42 of Set 15 | ponferrada
# Processing Record 43 of Set 15 | hanford
# Processing Record 44 of Set 15 | waingapu
# Processing Record 45 of Set 15 | yuzhou
# Processing Record 46 of Set 15 | aguimes
# Processing Record 47 of Set 15 | mainburg
# Processing Record 48 of Set 15 | marsabit
# Processing Record 49 of Set 15 | weyburn
# Processing Record 50 of Set 15 | yershichi
# Processing Record 1 of Set 16 | mwense
# Processing Record 2 of Set 16 | dauriya
# Processing Record 3 of Set 16 | kiunga
# Processing Record 4 of Set 16 | grahamstown
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Jamestown  42.0970  -79.2353     38.84        72          40
# 1         Cayenne   4.9333  -52.3333     75.24        88           0
# 2         Bakchar  57.0186   82.0711     32.86        91         100
# 3           Airai  -8.9266  125.4092     71.74        73          82
# 4       Killarney  52.0500   -9.5167     45.28        90          86
# 5   Makakilo City  21.3469 -158.0858     77.32        81           0
# 6  Ribeira Grande  38.5167  -28.7000     54.77        88          99
# 7          Hobart -42.8794  147.3294     66.06        51          20
# 8            Hilo  19.7297 -155.0900     76.28        91          40
# 9         Andenes  69.3143   16.1194     24.78        86          20
#
#    Wind Speed Country   Current Weather
# 0        8.05      US  scattered clouds
# 1        0.00      GF         clear sky
# 2       11.27      RU   overcast clouds
# 3        1.50      TL     broken clouds
# 4       11.99      IE   overcast clouds
# 5        5.75      US         clear sky
# 6        4.00      PT   overcast clouds
# 7       11.50      AU        few clouds
# 8        5.75      US  scattered clouds
# 9       25.32      NO        few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Weather'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "city", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Weather"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Jamestown      US  42.0970  -79.2353     38.84        72          40
# 1         Cayenne      GF   4.9333  -52.3333     75.24        88           0
# 2         Bakchar      RU  57.0186   82.0711     32.86        91         100
# 3           Airai      TL  -8.9266  125.4092     71.74        73          82
# 4       Killarney      IE  52.0500   -9.5167     45.28        90          86
# 5   Makakilo City      US  21.3469 -158.0858     77.32        81           0
# 6  Ribeira Grande      PT  38.5167  -28.7000     54.77        88          99
# 7          Hobart      AU -42.8794  147.3294     66.06        51          20
# 8            Hilo      US  19.7297 -155.0900     76.28        91          40
# 9         Andenes      NO  69.3143   16.1194     24.78        86          20
#
#    Wind Speed   Current Weather
# 0        8.05  scattered clouds
# 1        0.00         clear sky
# 2       11.27   overcast clouds
# 3        1.50     broken clouds
# 4       11.99   overcast clouds
# 5        5.75         clear sky
# 6        4.00   overcast clouds
# 7       11.50        few clouds
# 8        5.75  scattered clouds
# 9       25.32        few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                object
# Country             object
# Lat                float64
# Lng                float64
# Max Temp           float64
# Humidity             int64
# Cloudiness           int64
# Wind Speed         float64
# Current Weather     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
